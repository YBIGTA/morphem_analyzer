# %% [markdown]
# # 웹툰 관련 정보 크롤링
# <p>
# - 나무위키에서 웹툰과 관련된 단어들을 수집(고유명사)
#     1. 등장인물(캐릭터)
#     2.
# </p>
# <p>
# - 사전을 만들어야 하므로 형식에 맞게 csv파일로 저장
#     morpheme  | left | right | cost | tag | sub-tag | compound | 받침 | morpheme | component*5
#     백마탄, 0, 0, 0, NNP, 캐릭터-가우스전자, 0, T, 0,
# </p>

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pandas import DataFrame, Series

# %%
# 나무위키에서 네이버 웹툰이름과 링크 가져오기
wt_names_url = []
url_naver_wt = "https://namu.wiki/w/%EB%84%A4%EC%9D%B4%EB%B2%84%20%EC%9B%B9%ED%88%B0/%EC%97%B0%EC%9E%AC%EB%AA%A9%EB%A1%9D"

r1 = requests.get(url_naver_wt)
bs1 = BeautifulSoup(r_1.text, "lxml")

# %%
week_list = bs1.findAll("ul", {"class":"wiki-list"})

# %%
wt_list = week_list[1].findAll("li")

# %%
wt_list[1].find("p").find("a").text
# Out:
# '대학일기'

# %%
wt_list[1].find("p").findAll("a")[1]["href"]
# Out:
# 'http://comic.naver.com/webtoon/list.nhn?titleId=679519&weekday=mon'

# %%
for i, week in enumerate(week_list) :
    wt_list  = week_list[i]

# %%
for week in week_list:
    week.find()
# Out:
# [<ul class="wiki-list"><li><p>상위 문서: <a class="wiki-link-internal" href="/w/%EB%84%A4%EC%9D%B4%EB%B2%84%20%EC%9B%B9%ED%88%B0" title="네이버 웹툰">네이버 웹툰</a></p></li></ul>,
# ...

# %%
# 요일별로 중복되어 있는 웹툰 제외

wt_list = bs_1.findAll("", {"":""})
for item in wt_list:
    wt_name = item.find()
    wt_url = item.find()
    wt_list.append([wt_name, wt_url])

# %%
wt_names

# %%
# 등장인물 url 또는 등장인물 정보 가져오기
def get_characters(wt_name, wt_url):
    wt_characters = []
    
    r_wt = requests.get(wt_url)

    if : # 그 페이지에 등장인물 정보가 포함되어 있다면
        # 바로 가져오면 됨

    else : # 만약 페이지가 분리되어 있다면
        # 그 페이지로 들어감
        url_character = r_wt.find
        
    return wt_characters

# %%
for wt in wt_list :
